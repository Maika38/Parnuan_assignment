# %% [markdown]
# #Assignment 2 : Funnel Analysis

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# From visualization above shows the conversion funnel rate accross each stage, following these steps;
#
# 1. Customers opened application (100%): The funnel begins with 25 customers opening the appilcation, which represents 100 % of total users as an initial stage.
#
# 2. Onborading start (88%): At this stage, the number of users who joined onboarpding process(such as, the guideline video or step- by-step cards of how to use the website) was only 88 % of users (22 persons) who continuing participating from onboarding start.
#
# 3. Onboarding Complete( 72%) : From the amount of users who started onboarding, 72 % was completed onboarding process.
#
# 4. Home View(72%): The proportion of users who complete onboarding is equal to the proportion of users who access the home view. This reflects that users who completed onboarding process enable to see the home view of application.
#
# 5. Transaction submit (36%) : After the user enable to use the application, the record presents that only 36 % of the users is willing to submit the service transaction. It seems like many do not proceed to complete a transaction.
#
#
# Additionally, the drop down interaction allows users to filter of customer's platform, including IOS and Android.

# %% [markdown]
# # Requirement Answers
#
# ##1. What is the conversion rate at each funnel step?
#
# ![image.png](data:image/png;base64,...)

# %%
##3. One recommendation to improve conversion

# %% [markdown]
# ##2. Where is the biggest drop-off?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# From the percentage drop-off analysis, the process shows that the transaction summit has a biggest drop - off at 50 % after users reaching home view on both Android and iOS platforms. This indicates  although users are able to fully access and use the application, only half of them proceed to complete a transaction within this application.
#
#
#
# # aim to hit bonus !
# The comparision bar graph illustates amount of users between Android and iOS platforms. For the initial stage of app open stage, the number of users is relatively balanced between the two platforms with iOS having only one more user than Android, indicating similar adoption at the entry point.
#
# However, when examining the percentage drop-off rates across the early funnel stages (app open → onboarding start → onboarding complete), Android shows a higher drop-off compared to iOS. This set of data reflects that the functional or user experience in 'android' may be hard to use or gain the higher user engagement comparing to iOS platform.

# %% [markdown]
# ##3. One recommendation to improve conversion

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Overall, this demonstates that the probability that customers summiting the first transaction is relatively low. Only 36% from all users(9 out of 25 users) complete their first transaction, which corresponds to 50% of users who reach the home view. These percentage shows that the purpose of the application may not be effectively building the engagement or addressing customer's pain points of the customers, resulting in less users submitting their first transaction.
#
#
# To address this issue,
# 1. we can revise or conduct more research to better understand user needs and clarify the core purpose of the application in solving customer pain points.
#
# 2. After having the clear goals, user interface and experience are also important to elevate the first transaction. Making sure that the transaction processes are easy and convenient to understand in the sort time frame. Additionally, having a suitable design for target users. Addressing these areas might help increase the ammount of users completing their first transaction.
